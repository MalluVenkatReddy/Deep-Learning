# %%
Q1. What is an activation function in the context of artificial neural networks?

# %% [markdown]
# ##  An Activation Function decides whether a neuron should be activated or not. This means that it will decide whether the neuron's input to the network is important or not in the process of prediction using simpler mathematical operations

# %%
Q2. What are some common types of activation functions used in neural networks?

# %% [markdown]
# ## common types of activation functions
#
# 1.Sigmoid function
#
# 2.Relu
#
# 3.Relu Leak
#
# 4.Tanh
#
# 5.Softmax
#
# 6.Parametric Relu

# %%
Q3. How do activation functions affect the training process and performance of a neural network?

# %% [markdown]
# ## Simple threashoold function can not capture non linear patterns, for dealing such non linear we need activation functions.

# %%
Q4. How does the sigmoid activation function work? What are its advantages and disadvantages?

# %%
from IPython import display
display.Image("Sigmoid function.png")

# %% [markdown]
# ## Sigmoid / Logistic Activation Function
# This function takes any real value as input and outputs values in the range of 0 to 1. The larger the input (more positive), the closer the output value will be to 1.0, whereas the smaller the input (more negative), the closer the output will be to 0.0, as shown below.

# %% [markdown]
# ## Advantages of Sigmoid Function: -
# It provides Smooth gradient which helps us in preventing “jumps” in output values.
# Output values bound between 0 and 1, normalizing the output of each neuron.
# It provides clear predictions, i.e. very close to 1 or 0 which helps us to improve model performance.

# %% [markdown]
# ## Disadvantages of Sigmoid functions:
# It is most prone to gradient vanishing problem.
# Function output is not zero-centred.
# Power operations are relatively time-consuming which increases model complexity.

# %%
Q5.What is the rectified linear unit (ReLU) activation function? How does it differ from the sigmoid function?

# %%
from IPython import display
display.Image("ReLu.png")

# %% [markdown]
# ## ReLU boasts of training complex models/neural networks with constant values compared to sigmoid. Relu exhibits better efficiency: An advantage of ReLU, despite avoiding the vanishing gradients problem, is that it has a much lower run time max(0,f) and runs much faster than any sigmoid function.

# %%
Q6. What are the benefits of using the ReLU activation function over the sigmoid function?

# %% [markdown]
# ## More computationally efficient to compute than Sigmoid like functions since Relu just needs to pick max(0, x) and not perform expensive exponential operations as in Sigmoids. Relu : In practice, networks with Relu tend to show better convergence performance than sigmoid.

# %%
Q7. Explain the concept of "leaky ReLU" and how it addresses the vanishing gradient problem.

# %%
from IPython import display
display.Image("Leaky ReaLu.png")

# %% [markdown]
# ## Because ReLU is known for vanishing gradients, since any values less than zero are mapped to zero. This is true regardless of the number of layers. LeakyReLU on the other hand, maps the values less than zeros to a very small positive number. This prevents vanishing gradient from occurring

# %%
Q8. What is the purpose of the softmax activation function? When is it commonly used?

# %%
from IPython import display
display.Image("Softmax.png")

# %% [markdown]
# ## We will use softmax in multi class classification problem

# %%
Q9. What is the hyperbolic tangent (tanh) activation function? How does it compare to the sigmoid function?

# %%
from IPython import display
display.Image("tanH.png")

# %% [markdown]
# ## We observe that the gradient of tanh is four times greater than the gradient of the sigmoid function. This means that using the tanh activation function results in higher values of gradient during training and higher updates in the weights of the network.

# %%
from IPython import display
display.Image("Tanh_Sigmoid.png")
